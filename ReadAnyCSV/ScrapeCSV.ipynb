# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
variable = pd.read_csv('https://www.football-data.co.uk/new/IRL.csv')

# %%
variable
# Out:
#       Country             League  Season        Date   Time          Home  \
# 0     Ireland  Premier Division     2012  02/03/2012  19:05      Drogheda
# 1     Ireland  Premier Division     2012  02/03/2012  19:45    Derry City
# 2     Ireland  Premier Division     2012  02/03/2012  19:45  St. Patricks
# 3     Ireland  Premier Division     2012  02/03/2012  19:45     UC Dublin
# 4     Ireland  Premier Division     2012  02/03/2012  20:00      Monaghan
# ...       ...                ...     ...         ...    ...           ...
# 1990  Ireland   Premier Division    2022  30/09/2022  19:45       Dundalk
# 1991  Ireland   Premier Division    2022  30/09/2022  19:45  St. Patricks
# 1992  Ireland   Premier Division    2022  30/09/2022  20:00    Finn Harps
# 1993  Ireland   Premier Division    2022  01/10/2022  19:45  Sligo Rovers
# 1994  Ireland   Premier Division    2022  03/10/2022  19:45    Shelbourne
#
#                  Away  HG  AG Res     PH    PD    PA   MaxH  MaxD  MaxA  AvgH  \
# ...
